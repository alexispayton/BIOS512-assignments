# %% [markdown]
# Load the `tidyverse`, `tidygraph` and the `ggraph` packages.

# %%
library("tidyverse")
library("tidygraph")
library("ggraph")
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘tidygraph’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %% [markdown]
# Read in the `CSV` from the following link as `dolphin_nodes`.
#
# - http://users.dimi.uniud.it/~massimo.franceschet/ns/plugandplay/ggraph/dolphin_nodes.csv

# %%
dolphin_nodes = read_csv("http://users.dimi.uniud.it/~massimo.franceschet/ns/plugandplay/ggraph/dolphin_nodes.csv")
# Out:
# Parsed with column specification:
# cols(
#   name = col_character(),
#   sex = col_character()
# )

# %% [markdown]
# Read in the `CSV` from the following link as `dolphin_edges`.
# - http://users.dimi.uniud.it/~massimo.franceschet/ns/plugandplay/ggraph/dolphin_edges.csv

# %%
dolphin_edges = read_csv("http://users.dimi.uniud.it/~massimo.franceschet/ns/plugandplay/ggraph/dolphin_edges.csv")
# Out:
# Parsed with column specification:
# cols(
#   x = col_double(),
#   y = col_double()
# )

# %% [markdown]
# Preview each table. Do the columns make sense?

# %%
head(dolphin_nodes)
head(dolphin_edges)
# Out:
#   name       sex
# 1 Beak       M
# 2 Beescratch M
# 3 Bumper     M
# 4 CCL        F
# 5 Cross      M
# 6 DN16       F
#   x y
# 1 4  9
# 2 6 10
# 3 7 10
# 4 1 11
# 5 3 11
# 6 6 14

# %% [markdown]
# Using `tbl_graph` make a network called `dolphin_graph` from `dolphin_nodes` and `dolphin_edges`

# %%
dolphin_graph = tbl_graph(dolphin_nodes, dolphin_edges)

# %% [markdown]
# Prieview `dolphin_graph`. (Hint: use `print`)

# %%
dolphin_graph %>% print
# Out:
# # A tbl_graph: 62 nodes and 159 edges
# #
# # A directed acyclic simple graph with 1 component
# #
# # Node Data: 62 x 2 (active)
#   name       sex
#   <chr>      <chr>
# 1 Beak       M
# 2 Beescratch M
# 3 Bumper     M
# 4 CCL        F
# 5 Cross      M
# 6 DN16       F
# # … with 56 more rows
# #
# # Edge Data: 159 x 2
#    from    to
#   <int> <int>
# 1     4     9
# 2     6    10
# 3     7    10
# # … with 156 more rows

# %% [markdown]
# Make a basic network visualization with `ggraph`, `geom_node_point`, and `geom_node_link`.

# %%
ggraph(dolphin_graph) + 
  geom_node_point() + 
  geom_edge_link()
# Out:
# Using `sugiyama` as default layout
# plot without title

# %% [markdown]
# Create the same chart but this time use the `kk` layout and color the nodes by `sex`.

# %%
ggraph(dolphin_graph, layout = 'kk') + 
    geom_edge_link() + 
  geom_node_point(aes(color = sex))
# Out:
# plot without title
