# %%
# Load the libraries and set the resolution for your Notebook by "uncommenting" and running this cell

library("tidyverse")
library("palmerpenguins")
options(repr.plot.res = 300) #set plot resolution
# in geom_col can make bars stacked by doing geom_col(position = 'stack') or geom_col(position = 'dodge') to make 
#them next to each other
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Run this cell.
# What are the columns in the penguins dataset?

penguins %>% head
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# Let's make this figure 👇

# %% [markdown]
# <img src="penguin_plot.png" style="width: 650px" />

# %% [markdown]
# - What column in the `penguins` dataset is represented on each axis?
# - what column is mapped the color property of each chart?

# %% [markdown]
# **Using your answers above, fill in this code to re-create the above chart.**

# %%
options(repr.plot.width=5, repr.plot.height=3)

# add the dataset and column names to the code below 
p = ggplot(data = penguins, aes(x = flipper_length_mm, y = body_mass_g, color = species))

# add the correct geom below
p = p + geom_point()

scale_color_manual(values = c('purple','orange'))# changing point color
# run the cell? Did it work?
p

# %% [markdown]
# **What happens if you encode "sex" with point color instead of "species?"**

# %%
options(repr.plot.width=5, repr.plot.height=3)

# add your code below

ggplot(data = penguins, aes(x = flipper_length_mm, y = body_mass_g, color = sex)) + geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title
